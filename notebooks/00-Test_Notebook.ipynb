# %% [markdown]
# # Test notebook
#
# This is just a simple test notebook.

# %%
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nbs = [f for f in Path.cwd().glob("*.ipynb")]
print(f"There are {len(nbs)} fine notebooks in this folder!")
# Out:
# There are 1 fine notebooks in this folder!

# %%
x = np.arange(128)
plt.plot(x, np.sin(x/16), '-')
